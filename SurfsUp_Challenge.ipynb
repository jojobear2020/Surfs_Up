# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import datetime

from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_tobs = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == 6).all()
print(june_tobs)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
#  3. Convert the June temperatures to a list.
type(june_tobs)
# Out:
# list

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.

# Save the query results as a Pandas DataFrame and set the index to the date column
df_jun = pd.DataFrame(june_tobs, columns=['date','June temperature'])
df_jun.set_index(df_jun['date'], inplace=True)

# Sort the dataframe by date
df_jun = df_jun.sort_index()
print(df_jun.to_string(index=False))
# Out:
#        date  June temperature
#  2010-06-01              78.0
#  2010-06-01              73.0
#  2010-06-01              77.0
#  2010-06-01              69.0
#  2010-06-01              76.0
#  2010-06-01              71.0
#  2010-06-01              74.0
#  2010-06-01              70.0
#  2010-06-01              74.0
#  2010-06-02              78.0
#  2010-06-02              70.0
#  2010-06-02              76.0
#  2010-06-02              76.0
#  2010-06-02              71.0
#  2010-06-02              76.0
#  2010-06-02              76.0
#  2010-06-02              72.0
#  2010-06-02              76.0
#  2010-06-03              74.0
#  2010-06-03              78.0
#  2010-06-03              73.0
#  2010-06-03              72.0
#  2010-06-03              77.0
#  2010-06-03              76.0
#  2010-06-03              75.0
#  2010-06-03              78.0
#  2010-06-03              67.0
#  2010-06-04              73.0
#  2010-06-04              75.0
#  2010-06-04              75.0
# ...

# %%
# use the describe() function to calculate the mean, minimum, maximum, standard deviation, and percentiles
round(df_jun.describe())
# Out:
#        June temperature
# count            1700.0
# mean               75.0
# std                 3.0
# min                64.0
# 25%                73.0
# 50%                75.0
# 75%                77.0
# max                85.0

# %%
#plot to see the most occuring temperatures in June
df_jun.plot.hist(bins=8, title = "Hawaii Temperature Trend in June (2010-2017)")
# save praph
plot.savefig("analysis/jun_temp_occurence.png")

# %%
#plot June temp trend thru years
jun_graph = df_jun.plot(figsize = (16, 9),
                        sort_columns=True,
                        rot=45,
                        use_index=True,
                        legend=True,
                        grid=True,
                        color='b')
plot.ylabel('Temperature (F)', weight='bold')
plot.xlabel('Date', weight='bold')
plot.title("June Temperatures in Hawaii (2010-2017)", fontsize=20)
# Save the figure.
plot.savefig("analysis/jun_temp_trend.png")
plot.show()

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
december_tobs = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == 12).all()
print(december_tobs)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 7. Convert the December temperatures to a list.
type(december_tobs)
# Out:
# list

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df_dec = pd.DataFrame(december_tobs, columns=['date','December temperature'])
df_dec.set_index(df_dec['date'], inplace=True)

# Sort the dataframe by date
df_dec = df_dec.sort_index()
print(df_dec.to_string(index=False))
# Out:
#        date  December temperature
#  2010-12-01                  76.0
#  2010-12-01                  73.0
#  2010-12-01                  72.0
#  2010-12-01                  78.0
#  2010-12-01                  72.0
#  2010-12-01                  70.0
#  2010-12-01                  71.0
#  2010-12-01                  73.0
#  2010-12-02                  71.0
#  2010-12-02                  71.0
#  2010-12-02                  73.0
#  2010-12-02                  75.0
#  2010-12-02                  74.0
#  2010-12-02                  72.0
#  2010-12-02                  74.0
#  2010-12-02                  70.0
#  2010-12-03                  67.0
#  2010-12-03                  74.0
#  2010-12-03                  70.0
#  2010-12-03                  74.0
#  2010-12-03                  71.0
#  2010-12-03                  74.0
#  2010-12-03                  72.0
#  2010-12-03                  73.0
#  2010-12-04                  75.0
#  2010-12-04                  72.0
# ...

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
round(df_dec.describe())
# Out:
#        December temperature
# count                1517.0
# mean                   71.0
# std                     4.0
# min                    56.0
# 25%                    69.0
# 50%                    71.0
# 75%                    74.0
# max                    83.0

# %%
# plot to see occurence trend
df_dec.plot.hist(bins=8, title = "Hawaii Temperature Trend in December (2010-2017)")
# save graph
plot.savefig("analysis/dec_temp_occurence.png")

# %%
#plot December temp trend thru years
dec_graph = df_dec.plot(figsize = (16, 9),
                        sort_columns=True,
                        rot=45,
                        use_index=True,
                        legend=True,
                        grid=True,
                        color='b')
plot.ylabel('Temperature (F)', weight='bold')
plot.xlabel('Date', weight='bold')
plot.title("December Temperatures in Hawaii (2010-2017)", fontsize=20)
#save graph
plot.savefig("analysis/dec_temp_trend.png")
plot.show()

# %% [markdown]
# ## June and December - Combined Graph

# %%
import seaborn as sns

sns.kdeplot(df_dec['December temperature'], label='Dec', shade=True)
sns.kdeplot(df_jun['June temperature'], label='Jun', shade=True)
plot.xlabel('Temperature (F)')
plot.title("Temperatures in Hawaii (2010-2017)", fontsize=16)

#save graph
plot.savefig("analysis/jun_dec_temp_kdeplot.png")
plot.show()
